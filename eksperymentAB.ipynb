# %% [markdown]
# # Przeprowadzenie eksperymentu AB
#
# Zgodnie ze sprawozdaniem eksperyment AB przyjmuje następującą formę: _"Co miesiąc system będzie przydzielał użytkowników do dwóch różnych podgrup (grupy kontrolnej i grupy doświadczalnej). W rezultacie otrzymamy dwie grupy w każdym miesiącu: grupę kontrolną, korzystającą z portalu w sposób niezmieniony oraz grupę doświadczalną, która korzysta z portalu, ale z zastosowaniem naszego modelu. Pod koniec miesiąca zbierane są dane dotyczące czasu spędzanego przez użytkowników w obu grupach."_

# %% [markdown]
# ### Podział użytkowników na grupe kontrolną i doświadczalną
#
# Przy podziale zależy nam o zadbaniu o to, aby obie grupy były reprezentatywne. W tym celu dzielimy użytkowników na 3 klastry za pomocą modelu KMeans. W grupowaniu skupiamy się na atrybutach związnych ze sposobem interakcji użytkownika z interfejsem. Następnie równomiernie wybieramy osobników z klastrów, tak aby utworzyć 2. grupy badawcze. Zakładamy, że takie podejście pozwoli nam uzyskać podobne grupy, zróżnicowanych użytkowników.

# %% [markdown]
# Załadowanie danych dotyczących użytkowników

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

PATH_USERS = "data/v2/users.jsonl"
users_df = pd.read_json(PATH_USERS, lines=True) 

PATH_SESSION = "data/v2/sessions.jsonl"
session_df = pd.read_json(PATH_SESSION, lines=True)

# %% [markdown]
# Obliczenie długości trwania każdej sesji, na podstawie pliku session.jsonl

# %%
session_df['timestamp'] = pd.to_datetime(session_df['timestamp'])
session_df = session_df.sort_values(by='timestamp')
session_df['duration'] = session_df.groupby('session_id')['timestamp'].transform(lambda x: (x.max() - x.min()).total_seconds())
session_df
# Out:
#                     timestamp  user_id                track_id     event_type  \
# 17910 2022-11-24 08:27:56.000      145  5wDjsF1L2gLQ22kyvXiGUW           play
# 18562 2022-11-26 02:48:08.000      147  45S5WTQEGOB1VHr1Q4FuPl           play
# 18563 2022-11-26 02:50:20.200      147  45S5WTQEGOB1VHr1Q4FuPl           skip
# 18564 2022-11-26 02:50:20.200      147                          advertisement
# 18565 2022-11-26 02:50:29.200      147  1EzrEOXmMH3G43AXT1y7pA           play
# ...                       ...      ...                     ...            ...
# 4479  2023-11-24 11:31:30.883      112  0y60itmpH0aPKsFiGxmtnh           play
# 4480  2023-11-24 11:34:43.532      112  0y60itmpH0aPKsFiGxmtnh           skip
# 4481  2023-11-24 11:34:43.532      112  7fBv7CLKzipRk6EC6TWHOB           play
# 4482  2023-11-24 11:34:58.099      112  7fBv7CLKzipRk6EC6TWHOB           like
# 4483  2023-11-24 11:37:07.816      112  7fBv7CLKzipRk6EC6TWHOB           skip
#
#        session_id  duration
# 17910         700     0.000
# 18562         727  2467.194
# 18563         727  2467.194
# 18564         727  2467.194
# 18565         727  2467.194
# ...           ...       ...
# 4479          256  2948.816
# 4480          256  2948.816
# 4481          256  2948.816
# 4482          256  2948.816
# 4483          256  2948.816
#
# [20637 rows x 6 columns]

# %% [markdown]
# Zliczenie typów interakcji w ramach każdej sesji

# %%
session_summary_df = session_df.groupby('session_id').agg(
    duration=('duration', 'first'),
    user_id=('user_id', 'first'),
    num_play_events=('event_type', lambda x: (x == 'play').sum()),
    num_like_events=('event_type', lambda x: (x == 'like').sum()),
    num_skip_events=('event_type', lambda x: (x == 'skip').sum())
).reset_index()

session_summary_df = session_summary_df.set_index('session_id')
session_summary_df
# Out:
#             duration  user_id  num_play_events  num_like_events  \
# session_id
# 124         5989.342      101               29                2
# 125         7315.030      101               36                4
# 126         6357.135      101               24                1
# 127         4042.551      101               20                0
# 128         1265.413      101                6                0
# ...              ...      ...              ...              ...
# 780         2212.385      150               15                0
# 781         3223.586      150               21                2
# 782         1493.654      150                9                0
# 783         2176.177      150               11                0
# 784         6849.174      150               37                2
#
#             num_skip_events
# session_id
# 124                       1
# 125                       3
# 126                       0
# 127                       3
# 128                       0
# ...                     ...
# 780                       8
# 781                       6
# 782                       1
# 783                       1
# 784                       9
#
# [612 rows x 5 columns]

# %% [markdown]
# Normalizacja wartości atrybutów i podział sesji na klastry

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

features = ['num_play_events', 'num_like_events', 'num_skip_events', 'duration']

num_clusters = 3
scaler = StandardScaler()
df_scaled = scaler.fit_transform(session_summary_df[features])

kmeans = KMeans(n_clusters=num_clusters, random_state=42)
session_summary_df['cluster'] = kmeans.fit_predict(df_scaled)
session_summary_df
# Out:
# c:\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#             duration  user_id  num_play_events  num_like_events  \
# session_id
# 124         5989.342      101               29                2
# 125         7315.030      101               36                4
# 126         6357.135      101               24                1
# 127         4042.551      101               20                0
# 128         1265.413      101                6                0
# ...              ...      ...              ...              ...
# 780         2212.385      150               15                0
# 781         3223.586      150               21                2
# 782         1493.654      150                9                0
# 783         2176.177      150               11                0
# 784         6849.174      150               37                2
#
#             num_skip_events  cluster
# session_id
# 124                       1        2
# 125                       3        2
# 126                       0        2
# 127                       3        2
# 128                       0        1
# ...                     ...      ...
# 780                       8        1
# 781                       6        2
# 782                       1        1
# 783                       1        1
# 784                       9        2
#
# [612 rows x 6 columns]

# %% [markdown]
# Przydział użytkowników do klastrów

# %% [markdown]
# Dla każdego użytkownika sprawdzamy jakie klastry otrzymały powiązane z nim sesje i przydzielamy go do tej wsytępującej najczęściej

# %%
most_popular_cluster = session_summary.groupby('user_id')['cluster'].agg(lambda x: x.value_counts().idxmax())
users_df = users_df.merge(most_popular_cluster, how='left', on='user_id')
users_df
# Out:
#     user_id                name      city                      street  \
# 0       101      Konrad Gajzler   Wrocław              pl. Żurawia 38
# 1       102    Szymon Ciereszko   Wrocław         pl. Kasprowicza 536
# 2       103     Norbert Młodzik     Radom           ul. Lwowska 60/07
# 3       104          Patryk Boś  Warszawa            ul. Ciasna 53/93
# 4       105  Elżbieta Strządała    Poznań           al. Niecała 10/94
# 5       106      Kajetan Jeszke    Kraków            pl. Jagodowa 862
# 6       107  Mikołaj Dzikiewicz    Kraków   aleja Wróblewskiego 73/41
# 7       108      Maciej Klinger  Warszawa          ul. Brzozowa 43/01
# 8       109   Ryszard Rzeszutko    Poznań             ulica Glówna 18
# 9       110         Leon Pałyga    Kraków        ulica Malinowa 47/92
# 10      111       Mariusz Krzan    Gdynia          al. Toruńska 49/97
# 11      112    Jędrzej Podgórny     Radom     aleja Paderewskiego 167
# 12      113       Marcin Iwanow    Kraków               pl. Daleka 78
# 13      114        Sandra Dulas  Warszawa       aleja Traugutta 89/17
# 14      115      Andrzej Bartel     Radom            pl. Pałacowa 106
# 15      116          Anita Gral    Gdynia             al. Lubelska 41
# 16      117       Dagmara Matla    Kraków            al. Graniczna 29
# 17      118       Borys Tatarek    Gdynia         ul. Turkusowa 70/06
# 18      119      Gabriel Krefta    Gdynia             plac Jadwigi 04
# 19      120      Ksawery Dłubak   Wrocław           plac Pocztowa 998
# 20      121       Eliza Brejnak    Kraków              plac Dolna 193
# 21      122  Albert Buszkiewicz   Wrocław   plac Makuszyńskiego 51/07
# 22      123       Malwina Keler    Gdynia             aleja Sowia 610
# 23      124      Kornelia Kołak  Warszawa    plac Malczewskiego 57/44
# 24      125         Piotr Durys  Warszawa               ul. Łąkowa 69
# 25      126     Radosław Sołtan    Kraków            ul. Chabrowa 780
# 26      127    Radosław Wojczuk   Wrocław             ul. Pałacowa 85
# 27      128     Dariusz Pietraś   Wrocław           plac Cmentarna 71
# 28      129      Kacper Małocha    Kraków         pl. Popiełuszki 158
# 29      130   Marika Błażejczak  Szczecin        aleja Poprzeczna 548
# 30      131          Adam Bobak   Wrocław      al. Szymanowskiego 820
# 31      132         Olga Faruga  Szczecin          plac Stolarska 527
# 32      133       Szymon Grodek    Poznań        aleja Bydgoska 35/52
# 33      134      Kornel Labocha    Poznań           aleja Cedrowa 566
# 34      135     Fryderyk Wesoły   Wrocław          ulica Staffa 18/25
# 35      136         Liwia Fidor    Poznań   al. Żwirki i Wigury 73/77
# 36      137     Oliwier Kapałka   Wrocław            ulica Staffa 478
# 37      138       Ernest Mainka  Warszawa            ul. Wierzbowa 81
# 38      139       Juliusz Dyrek  Szczecin          aleja Chabrowa 743
# 39      140    Anna Maria Jessa     Radom                al. Mała 645
# 40      141            Ida Liss    Gdynia  al. Jana Sobieskiego 23/51
# 41      142        Łukasz Latko  Szczecin            al. Młynarska 31
# 42      143      Bartek Kustosz    Kraków        ul. Sucharskiego 851
# 43      144    Karina Garczarek     Radom           ul. Korfantego 19
# 44      145         Mateusz Bik  Szczecin           pl. Rumiankowa 13
# 45      146    Patryk Majerczyk     Radom           pl. Strumykowa 17
# 46      147       Rafał Kulczak  Szczecin              aleja Prusa 13
# 47      148       Nikodem Goral     Radom            ulica Średnia 09
# 48      149         Józef Dułak  Warszawa      plac Mickiewicza 66/19
# 49      150         Adam Pacyga     Radom       ulica Turystyczna 385
#
#                                      favourite_genres  premium_user  cluster
# 0    [blues rock, brill building pop, argentine rock]         False        2
# 1                           [mpb, funk, new romantic]         False        2
# 2                 [new wave, folk rock, country rock]         False        0
# 3                 [tropical, folk rock, classic rock]         False        2
# 4               [post-teen pop, pop rock, latin rock]         False        1
# 5              [classic rock, hard rock, quiet storm]         False        0
# 6                  [vocal jazz, adult standards, mpb]         False        2
# 7                    [album rock, metal, quiet storm]         False        2
# 8                [latin alternative, latin, ranchera]          True        0
# 9                       [rock, latin pop, vocal jazz]          True        1
# 10                    [motown, latin pop, roots rock]          True        1
# 11        [new romantic, post-teen pop, new wave pop]          True        0
# 12                               [j-pop, latin, rock]          True        0
# 13               [psychedelic rock, latin, latin pop]         False        2
# 14            [mellow gold, classic rock, latin rock]          True        2
# 15           [brill building pop, europop, soft rock]         False        1
# 16             [j-pop, adult standards, country rock]         False        2
# 17              [latin rock, soul, singer-songwriter]         False        0
# 18    [brill building pop, psychedelic rock, europop]          True        2
# 19                   [rock, mandopop, argentine rock]         False        2
# 20             [folk, italian adult pop, quiet storm]         False        2
# 21                               [rock, folk, motown]          True        1
# 22         [singer-songwriter, latin rock, hoerspiel]         False        0
# 23           [album rock, permanent wave, vocal jazz]          True        1
# 24  [country rock, latin alternative, permanent wave]         False        0
# 25            [album rock, italian adult pop, lounge]          True        2
# 26                     [latin pop, j-pop, blues rock]         False        2
# 27        [classic rock, singer-songwriter, tropical]          True        1
# 28    [modern rock, new romantic, brill building pop]          True        1
# 29                 [psychedelic rock, hard rock, pop]         False        2
# 30        [alternative metal, new romantic, new wave]          True        1
# 31        [dance pop, italian adult pop, modern rock]          True        0
# 32                 [modern rock, europop, album rock]          True        0
# 33              [j-pop, psychedelic rock, latin rock]          True        0
# 34                [mellow gold, latin rock, new wave]         False        2
# 35                [j-pop, new wave pop, classic rock]         False        2
# 36           [j-pop, regional mexican, post-teen pop]         False        2
# 37       [alternative rock, new wave, argentine rock]          True        1
# 38  [brill building pop, vocal jazz, italian adult...          True        1
# 39                                 [metal, pop, folk]         False        2
# 40                    [hoerspiel, country rock, funk]          True        1
# 41           [latin rock, mellow gold, post-teen pop]          True        2
# 42                         [metal, modern rock, soul]         False        2
# 43                         [rock, new wave, tropical]          True        0
# 44                    [folk, funk, alternative metal]          True        1
# 45   [alternative metal, adult standards, roots rock]          True        0
# 46                      [latin pop, funk, blues rock]          True        0
# 47                 [tropical, regional mexican, funk]         False        1
# 48     [latin pop, brill building pop, post-teen pop]          True        2
# 49      [soft rock, adult standards, rock en espanol]         False        1

# %% [markdown]
# Podział użytkowników na grupy badawcze

# %%
sorted_users_df = users_df.copy()
sorted_users_df.sort_values('cluster', ascending=False, inplace=True)

group_A = pd.DataFrame(columns=sorted_users_df.columns)
group_B = pd.DataFrame(columns=sorted_users_df.columns)

temp = 0
for index, row in users_df.iterrows():
    if temp % 2 == 0:
        group_A.loc[index] = row.copy()
    if temp % 2 != 0:
        group_B.loc[index] = row.copy()
    temp += 1

# %% [markdown]
# Zapis grup do plików CSV

# %%
group_A.to_csv('./data/experiment/groupA.csv', index=False)
group_B.to_csv('./data/experiment/groupB.csv', index=False)

# %% [markdown]
# Obliczenie średniej długości sesji dla każdej grupy

# %%
import numpy as np 

def calculate_mean_duration_user(user):
    user_id = user['user_id']
    user_sessions_df = session_summary_df.loc[session_summary_df['user_id'] == user_id].copy()
    return np.mean(user_sessions_df['duration'])
    
def calculate_mean_duration_group(group):
    users_means = []
    for index, row in group.iterrows():
        mean_session_duration = calculate_mean_duration_user(row.copy())
        users_means.append(mean_session_duration)
    return np.mean(users_means)

print(f'Mean session duration for group A: {calculate_mean_duration_group(group_A)}')
print(f'Mean session duration for group B: {calculate_mean_duration_group(group_B)}')
# Out:
# Mean session duration for group A: 3408.306205630371
# Mean seession duration fro group B: 3242.8546980233386

# %% [markdown]
# W biznesowym środowisku zakładamy nastepujący sposób przeprowadzania eksperymentu AB:
#
# 1. Na początku miesiąca przydzielamy użytkowników do grup badawczych za pomocą powyższego kodu;
# 2. Dla grupy B serwis Pozytywka zostaje wzbogacony o model klasyfikacyjny (bazowy lub docelowy);
# 3. Pod koniec miesiąca aktualizujemy dane o użytkownikach (w tym plik sessions.jsonl, niezbędny do przeprowadzenia eksperymentu);
# 4. W celu ewaluacji eksperymentu wyorzystujemy serwis, który zwórci nam informację o średnim czasie sesji każdej grupy.
#
# Za pomocą wygenerowanych informacji, można jednoznacznie stwierdzić czy wprowadzony model z sukcesem doprowadził do wzrostu zaangażowania użytkownika (czasu spędzonego w serwisie).

# %% [markdown]
# Po wcześniejszym uruchomieniu serwisu z poziomu folderu services, za pomoca komendy: uvicorn main:app --reload, eksperyment mozna przeprowadzić wykonując poniższą komórkę

# %%
import requests
import json

response = requests.get("http://127.0.0.1:8000/ABexperiment")

if response.status_code == 200:
    response_data = json.loads(response.text)
    print(response_data)
else:
    print(f"Error: {response.status_code}")
# Out:
# {'no model': 3408.306205630371, 'model': 3242.8546980233386, 'time': '2024-01-19T22:40:50.817635'}
